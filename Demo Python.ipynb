# %%
print(1+2)
# Out:
# 3

# %%
print('hi my name is punit')
# Out:
# hi my name is punit

# %%
def gauss(n):
    return (n*(n+1))/2

# %%
gauss(100) == sum(range(101))
# Out:
# True

# %%
sum(range(101))
# Out:
# 5050

# %%
gauss(100)
# Out:
# 5050.0
